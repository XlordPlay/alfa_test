# %%
import pandas as pd

# %%
file_path = "/home/xlordplay/alfa_test_tasks/alfa_test/data/Input data/data_prep.tab"  

df = pd.read_csv(file_path, sep="\t")

df.head()
# Out:
#             SEGM_DATE  CLIENT_ID  AVG_MG  MIN_MG  MAX_MG  COUNT_TR  \
# 0  01MAR2012:00:00:00  1-ET-1502    4.00       4       4         1
# 1  01APR2012:00:00:00  1-ET-1502    6.25       1      19         4
# 2  01MAY2012:00:00:00  1-ET-1502    6.83       1      19         6
# 3  01JUN2012:00:00:00  1-ET-1502    6.29       1      19         7
# 4  01JUL2012:00:00:00  1-ET-1502   10.60       1      30         5
#
#    SUM_TR_TOTAL    SUM_TR  RECENTY  AVG_SKU  ...  PROFIT_GROUP_ID  \
# 0        3214.5   3316.62       13     5.00  ...              NaN
# 1       13764.0  14673.23       10    10.50  ...              4.0
# 2       23889.0  25500.05       25    11.50  ...              3.0
# 3       25101.5  26749.93        8    10.86  ...              3.0
# 4       32506.0  34514.59       10    20.80  ...              3.0
#
#    CHANGE_PROFIT_GROUP_ID  CHANGE_SEGMENT_ID  PVAL_GROUP_CHANGE0  \
# 0                     NaN                NaN                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEGM_DATE                 19 non-null     object
#  1   CLIENT_ID                 19 non-null     object
#  2   AVG_MG                    19 non-null     float64
#  3   MIN_MG                    19 non-null     int64
#  4   MAX_MG                    19 non-null     int64
#  5   COUNT_TR                  19 non-null     int64
#  6   SUM_TR_TOTAL              19 non-null     float64
#  7   SUM_TR                    19 non-null     float64
#  8   RECENTY                   19 non-null     int64
#  9   AVG_SKU                   19 non-null     float64
#  10  AVG_COUNT_TR              19 non-null     float64
#  11  MIN_COUNT_TR              19 non-null     int64
#  12  MAX_COUNT_TR              19 non-null     int64
# ...

# %%
df.describe()
# Out:
#           AVG_MG     MIN_MG     MAX_MG   COUNT_TR  SUM_TR_TOTAL        SUM_TR  \
# count  19.000000  19.000000  19.000000  19.000000     19.000000     19.000000
# mean    5.504211   1.842105  13.000000   4.473684  14331.657895  15182.841579
# std     2.955609   1.424514  10.132456   2.457831  10431.235702  11078.498519
# min     2.000000   1.000000   3.000000   1.000000   1263.500000   1344.500000
# 25%     3.170000   1.000000   6.000000   2.000000   5294.750000   5665.000000
# 50%     4.000000   1.000000   6.000000   4.000000  13560.500000  14349.060000
# 75%     6.915000   2.000000  20.500000   6.500000  21584.000000  22657.570000
# max    11.250000   6.000000  30.000000   9.000000  33490.500000  35676.880000
#
#          RECENTY    AVG_SKU  AVG_COUNT_TR  MIN_COUNT_TR  ...  \
# count  19.000000  19.000000     19.000000     19.000000  ...
# mean   19.210526   8.536842      1.491053      0.368421  ...
# std    18.695154   5.578050      0.818942      0.597265  ...
# ...

# %%
update_df = pd.read_csv("/home/xlordplay/alfa_test_tasks/alfa_test/data/data_prep_transforme.csv")
update_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Columns: 176 entries, SEGM_DATE to EM_SEGMENT_2
# dtypes: float64(133), int64(17), object(26)
# memory usage: 26.3+ KB

# %%
update_df.describe()
# Out:
#           AVG_MG   AVG_MG_1   AVG_MG_2     MIN_MG   MIN_MG_1   MIN_MG_2  \
# count  19.000000  18.000000  17.000000  19.000000  18.000000  17.000000
# mean    5.504211   5.400000   5.335294   1.842105   1.833333   1.588235
# std     2.955609   3.005164   3.084700   1.424514   1.465285   1.064121
# min     2.000000   2.000000   2.000000   1.000000   1.000000   1.000000
# 25%     3.170000   3.155000   3.140000   1.000000   1.000000   1.000000
# 50%     4.000000   3.750000   3.500000   1.000000   1.000000   1.000000
# 75%     6.915000   6.747500   6.830000   2.000000   2.000000   2.000000
# max    11.250000  11.250000  11.250000   6.000000   6.000000   4.000000
#
#           MAX_MG   MAX_MG_1   MAX_MG_2   COUNT_TR  ...  PVAL_GROUP_CHANGE1_2  \
# count  19.000000  18.000000  17.000000  19.000000  ...             13.000000
# mean   13.000000  12.055556  12.352941   4.473684  ...              0.268089
# std    10.132456   9.526880   9.733583   2.457831  ...              0.252814
# ...

# %%
update_df.head(10)
# Out:
#             SEGM_DATE  CLIENT_ID  AVG_MG  AVG_MG_1  AVG_MG_2  MIN_MG  \
# 0  01APR2012:00:00:00  1-ET-1502    6.25       NaN       NaN       1
# 1  01APR2013:00:00:00  1-ET-1502    2.50      6.25       NaN       1
# 2  01AUG2012:00:00:00  1-ET-1502    7.00      2.50      6.25       2
# 3  01AUG2013:00:00:00  1-ET-1502    3.50      7.00      2.50       1
# 4  01DEC2012:00:00:00  1-ET-1502    3.14      3.50      7.00       1
# 5  01FEB2013:00:00:00  1-ET-1502    2.00      3.14      3.50       1
# 6  01JAN2013:00:00:00  1-ET-1502    3.14      2.00      3.14       1
# 7  01JAN2014:00:00:00  1-ET-1502   11.25      3.14      2.00       1
# 8  01JUL2012:00:00:00  1-ET-1502   10.60     11.25      3.14       1
# 9  01JUL2013:00:00:00  1-ET-1502    3.50     10.60     11.25       1
#
#    MIN_MG_1  MIN_MG_2  MAX_MG  MAX_MG_1  ...              MODIFY_DATE_2  \
# 0       NaN       NaN      19       NaN  ...                        NaN
# ...

# %%
missing_values = update_df[['MIN_LATENCY','MIN_LATENCY_2', 'AVG_LATENCY', 'MAX_LATENCY']].isna().sum()
print(missing_values)
# Out:
# MIN_LATENCY      2
# MIN_LATENCY_2    4
# AVG_LATENCY      2
# MAX_LATENCY      2
# dtype: int64
